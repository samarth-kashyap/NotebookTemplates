# %% [markdown]
# <a href="https://colab.research.google.com/github/samarth-kashyap/NotebookTemplates/blob/main/run_reduced_v11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install numpyro
# Out:
# Collecting numpyro
#   Downloading numpyro-0.8.0-py3-none-any.whl (264 kB)
#      |████████████████████████████████| 264 kB 21.4 MB/s
# Requirement already satisfied: jaxlib>=0.1.65 in /usr/local/lib/python3.7/dist-packages (from numpyro) (0.1.71+cuda111)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from numpyro) (4.62.3)
# Requirement already satisfied: jax>=0.2.13 in /usr/local/lib/python3.7/dist-packages (from numpyro) (0.2.25)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from jax>=0.2.13->numpyro) (3.10.0.2)
# Requirement already satisfied: scipy>=1.2.1 in /usr/local/lib/python3.7/dist-packages (from jax>=0.2.13->numpyro) (1.4.1)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.7/dist-packages (from jax>=0.2.13->numpyro) (0.12.0)
# Requirement already satisfied: numpy>=1.18 in /usr/local/lib/python3.7/dist-packages (from jax>=0.2.13->numpyro) (1.19.5)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.7/dist-packages (from jax>=0.2.13->numpyro) (3.3.0)
# Requirement already satisfied: flatbuffers<3.0,>=1.12 in /usr/local/lib/python3.7/dist-packages (from jaxlib>=0.1.65->numpyro) (2.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from absl-py->jax>=0.2.13->numpyro) (1.15.0)
# Installing collected packages: numpyro
# Successfully installed numpyro-0.8.0

# %%
# !wget ftp://ftp.tifr.res.in/g.samarth/two-params-mcmc/.dimhyper
# !wget ftp://ftp.tifr.res.in/g.samarth/two-params-mcmc/.n0-lmin-lmax.dat

# !wget ftp://ftp.tifr.res.in/g.samarth/two-params-mcmc/true_params.npy
# !wget ftp://ftp.tifr.res.in/g.samarth/two-params-mcmc/evals_model.npy
# !wget ftp://ftp.tifr.res.in/g.samarth/two-params-mcmc/acoeffs_true.npy
# !wget ftp://ftp.tifr.res.in/g.samarth/two-params-mcmc/acoeffs_sigma.npy

# !wget ftp://ftp.tifr.res.in/g.samarth/two-params-mcmc/ell0_arr.npy
# !wget ftp://ftp.tifr.res.in/g.samarth/two-params-mcmc/omega0_arr.npy
# !wget ftp://ftp.tifr.res.in/g.samarth/two-params-mcmc/dom_dell_arr.npy

# !wget ftp://ftp.tifr.res.in/g.samarth/two-params-mcmc/cind_arr.npy
# !wget ftp://ftp.tifr.res.in/g.samarth/two-params-mcmc/sind_arr.npy

# !wget ftp://ftp.tifr.res.in/g.samarth/two-params-mcmc/RL_poly.npy
# !wget ftp://ftp.tifr.res.in/g.samarth/two-params-mcmc/.dimhyper

# !wget ftp://ftp.tifr.res.in/g.samarth/two-params-mcmc/param_coeff.npy
# !wget ftp://ftp.tifr.res.in/g.samarth/two-params-mcmc/param_coeff_M.npy
# !wget ftp://ftp.tifr.res.in/g.samarth/two-params-mcmc/sparse_idx.npy
# !wget ftp://ftp.tifr.res.in/g.samarth/two-params-mcmc/sparse_idx_M.npy
# !wget ftp://ftp.tifr.res.in/g.samarth/two-params-mcmc/fixed_part.npy
# !wget ftp://ftp.tifr.res.in/g.samarth/two-params-mcmc/fixed_part_M.npy

# !wget ftp://ftp.tifr.res.in/g.samarth/two-params-mcmc/fixed_bkm.npy
# !wget ftp://ftp.tifr.res.in/g.samarth/two-params-mcmc/noc_bkm.npy
# !wget ftp://ftp.tifr.res.in/g.samarth/two-params-mcmc/k_arr.npy
# !wget ftp://ftp.tifr.res.in/g.samarth/two-params-mcmc/p_arr.npy
# Out:
# --2021-12-16 16:26:38--  ftp://ftp.tifr.res.in/g.samarth/two-params-mcmc/.dimhyper
#            => ‘.dimhyper’
# Resolving ftp.tifr.res.in (ftp.tifr.res.in)... 158.144.1.37, 2406:f00:1:1::70
# Connecting to ftp.tifr.res.in (ftp.tifr.res.in)|158.144.1.37|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /g.samarth/two-params-mcmc ... done.
# ==> SIZE .dimhyper ... 5
# ==> PASV ... done.    ==> RETR .dimhyper ... done.
# Length: 5 (unauthoritative)
#
# .dimhyper           100%[===================>]       5  --.-KB/s    in 0s
#
# 2021-12-16 16:26:41 (746 KB/s) - ‘.dimhyper’ saved [5]
#
# --2021-12-16 16:26:42--  ftp://ftp.tifr.res.in/g.samarth/two-params-mcmc/true_params.npy
#            => ‘true_params.npy’
# Resolving ftp.tifr.res.in (ftp.tifr.res.in)... 158.144.1.37, 2406:f00:1:1::70
# Connecting to ftp.tifr.res.in (ftp.tifr.res.in)|158.144.1.37|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /g.samarth/two-params-mcmc ... done.
# ==> SIZE true_params.npy ... 192
# ==> PASV ... done.    ==> RETR true_params.npy ... done.
# Length: 192 (unauthoritative)
#
# true_params.npy     100%[===================>]     192  --.-KB/s    in 0.01s
#
# 2021-12-16 16:26:45 (12.6 KB/s) - ‘true_params.npy’ saved [192]
#
# --2021-12-16 16:26:45--  ftp://ftp.tifr.res.in/g.samarth/two-params-mcmc/evals_model.npy
#            => ‘evals_model.npy’
# Resolving ftp.tifr.res.in (ftp.tifr.res.in)... 158.144.1.37, 2406:f00:1:1::70
# Connecting to ftp.tifr.res.in (ftp.tifr.res.in)|158.144.1.37|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /g.samarth/two-params-mcmc ... done.
# ==> SIZE evals_model.npy ... 951288
# ==> PASV ... done.    ==> RETR evals_model.npy ... done.
# Length: 951288 (929K) (unauthoritative)
#
# evals_model.npy     100%[===================>] 928.99K   527KB/s    in 1.8s
#
# 2021-12-16 16:26:51 (527 KB/s) - ‘evals_model.npy’ saved [951288]
#
# --2021-12-16 16:26:51--  ftp://ftp.tifr.res.in/g.samarth/two-params-mcmc/acoeffs_true.npy
#            => ‘acoeffs_true.npy’
# Resolving ftp.tifr.res.in (ftp.tifr.res.in)... 158.144.1.37, 2406:f00:1:1::70
# Connecting to ftp.tifr.res.in (ftp.tifr.res.in)|158.144.1.37|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /g.samarth/two-params-mcmc ... done.
# ==> SIZE acoeffs_true.npy ... 2024
# ==> PASV ... done.    ==> RETR acoeffs_true.npy ... done.
# Length: 2024 (2.0K) (unauthoritative)
#
# acoeffs_true.npy    100%[===================>]   1.98K  --.-KB/s    in 0.01s
#
# 2021-12-16 16:26:55 (160 KB/s) - ‘acoeffs_true.npy’ saved [2024]
#
# --2021-12-16 16:26:55--  ftp://ftp.tifr.res.in/g.samarth/two-params-mcmc/acoeffs_sigma.npy
#            => ‘acoeffs_sigma.npy’
# Resolving ftp.tifr.res.in (ftp.tifr.res.in)... 158.144.1.37, 2406:f00:1:1::70
# Connecting to ftp.tifr.res.in (ftp.tifr.res.in)|158.144.1.37|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /g.samarth/two-params-mcmc ... done.
# ==> SIZE acoeffs_sigma.npy ... 2024
# ==> PASV ... done.    ==> RETR acoeffs_sigma.npy ... done.
# Length: 2024 (2.0K) (unauthoritative)
#
# acoeffs_sigma.npy   100%[===================>]   1.98K  --.-KB/s    in 0.007s
#
# 2021-12-16 16:26:59 (304 KB/s) - ‘acoeffs_sigma.npy’ saved [2024]
#
# --2021-12-16 16:26:59--  ftp://ftp.tifr.res.in/g.samarth/two-params-mcmc/ell0_arr.npy
#            => ‘ell0_arr.npy’
# Resolving ftp.tifr.res.in (ftp.tifr.res.in)... 158.144.1.37, 2406:f00:1:1::70
# Connecting to ftp.tifr.res.in (ftp.tifr.res.in)|158.144.1.37|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /g.samarth/two-params-mcmc ... done.
# ==> SIZE ell0_arr.npy ... 760
# ==> PASV ... done.    ==> RETR ell0_arr.npy ... done.
# Length: 760 (unauthoritative)
#
# ell0_arr.npy        100%[===================>]     760  --.-KB/s    in 0.001s
#
# 2021-12-16 16:27:03 (1.08 MB/s) - ‘ell0_arr.npy’ saved [760]
#
# --2021-12-16 16:27:03--  ftp://ftp.tifr.res.in/g.samarth/two-params-mcmc/omega0_arr.npy
#            => ‘omega0_arr.npy’
# Resolving ftp.tifr.res.in (ftp.tifr.res.in)... 158.144.1.37, 2406:f00:1:1::70
# Connecting to ftp.tifr.res.in (ftp.tifr.res.in)|158.144.1.37|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /g.samarth/two-params-mcmc ... done.
# ==> SIZE omega0_arr.npy ... 760
# ==> PASV ... done.    ==> RETR omega0_arr.npy ... done.
# Length: 760 (unauthoritative)
#
# omega0_arr.npy      100%[===================>]     760  --.-KB/s    in 0.002s
#
# 2021-12-16 16:27:07 (375 KB/s) - ‘omega0_arr.npy’ saved [760]
#
# --2021-12-16 16:27:07--  ftp://ftp.tifr.res.in/g.samarth/two-params-mcmc/dom_dell_arr.npy
#            => ‘dom_dell_arr.npy’
# Resolving ftp.tifr.res.in (ftp.tifr.res.in)... 158.144.1.37, 2406:f00:1:1::70
# Connecting to ftp.tifr.res.in (ftp.tifr.res.in)|158.144.1.37|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /g.samarth/two-params-mcmc ... done.
# ==> SIZE dom_dell_arr.npy ... 760
# ==> PASV ... done.    ==> RETR dom_dell_arr.npy ... done.
# Length: 760 (unauthoritative)
#
# dom_dell_arr.npy    100%[===================>]     760  --.-KB/s    in 0s
#
# 2021-12-16 16:27:10 (91.4 MB/s) - ‘dom_dell_arr.npy’ saved [760]
#
# --2021-12-16 16:27:10--  ftp://ftp.tifr.res.in/g.samarth/two-params-mcmc/cind_arr.npy
#            => ‘cind_arr.npy’
# Resolving ftp.tifr.res.in (ftp.tifr.res.in)... 158.144.1.37, 2406:f00:1:1::70
# Connecting to ftp.tifr.res.in (ftp.tifr.res.in)|158.144.1.37|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /g.samarth/two-params-mcmc ... done.
# ==> SIZE cind_arr.npy ... 160
# ==> PASV ... done.    ==> RETR cind_arr.npy ... done.
# Length: 160 (unauthoritative)
#
# cind_arr.npy        100%[===================>]     160  --.-KB/s    in 0.03s
#
# 2021-12-16 16:27:14 (6.04 KB/s) - ‘cind_arr.npy’ saved [160]
#
# --2021-12-16 16:27:14--  ftp://ftp.tifr.res.in/g.samarth/two-params-mcmc/sind_arr.npy
#            => ‘sind_arr.npy’
# Resolving ftp.tifr.res.in (ftp.tifr.res.in)... 158.144.1.37, 2406:f00:1:1::70
# Connecting to ftp.tifr.res.in (ftp.tifr.res.in)|158.144.1.37|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /g.samarth/two-params-mcmc ... done.
# ==> SIZE sind_arr.npy ... 144
# ==> PASV ... done.    ==> RETR sind_arr.npy ... done.
# Length: 144 (unauthoritative)
#
# sind_arr.npy        100%[===================>]     144  --.-KB/s    in 0s
#
# 2021-12-16 16:27:20 (17.1 MB/s) - ‘sind_arr.npy’ saved [144]
#
# --2021-12-16 16:27:20--  ftp://ftp.tifr.res.in/g.samarth/two-params-mcmc/RL_poly.npy
#            => ‘RL_poly.npy’
# Resolving ftp.tifr.res.in (ftp.tifr.res.in)... 158.144.1.37, 2406:f00:1:1::70
# Connecting to ftp.tifr.res.in (ftp.tifr.res.in)|158.144.1.37|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /g.samarth/two-params-mcmc ... done.
# ==> SIZE RL_poly.npy ... 1141520
# ==> PASV ... done.    ==> RETR RL_poly.npy ... done.
# Length: 1141520 (1.1M) (unauthoritative)
#
# RL_poly.npy         100%[===================>]   1.09M   744KB/s    in 1.5s
#
# 2021-12-16 16:27:27 (744 KB/s) - ‘RL_poly.npy’ saved [1141520]
#
# --2021-12-16 16:27:27--  ftp://ftp.tifr.res.in/g.samarth/two-params-mcmc/.dimhyper
#            => ‘.dimhyper.1’
# Resolving ftp.tifr.res.in (ftp.tifr.res.in)... 158.144.1.37, 2406:f00:1:1::70
# Connecting to ftp.tifr.res.in (ftp.tifr.res.in)|158.144.1.37|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /g.samarth/two-params-mcmc ... done.
# ==> SIZE .dimhyper ... 5
# ==> PASV ... done.    ==> RETR .dimhyper ... done.
# Length: 5 (unauthoritative)
#
# .dimhyper.1         100%[===================>]       5  --.-KB/s    in 0s
#
# 2021-12-16 16:27:30 (860 KB/s) - ‘.dimhyper.1’ saved [5]
#
# --2021-12-16 16:27:30--  ftp://ftp.tifr.res.in/g.samarth/two-params-mcmc/param_coeff.npy
#            => ‘param_coeff.npy’
# Resolving ftp.tifr.res.in (ftp.tifr.res.in)... 158.144.1.37, 2406:f00:1:1::70
# Connecting to ftp.tifr.res.in (ftp.tifr.res.in)|158.144.1.37|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /g.samarth/two-params-mcmc ... done.
# ==> SIZE param_coeff.npy ... 58586528
# ==> PASV ... done.    ==> RETR param_coeff.npy ... done.
# Length: 58586528 (56M) (unauthoritative)
#
# param_coeff.npy     100%[===================>]  55.87M  11.0MB/s    in 6.5s
#
# 2021-12-16 16:27:41 (8.59 MB/s) - ‘param_coeff.npy’ saved [58586528]
#
# --2021-12-16 16:27:42--  ftp://ftp.tifr.res.in/g.samarth/two-params-mcmc/param_coeff_M.npy
#            => ‘param_coeff_M.npy’
# Resolving ftp.tifr.res.in (ftp.tifr.res.in)... 158.144.1.37, 2406:f00:1:1::70
# Connecting to ftp.tifr.res.in (ftp.tifr.res.in)|158.144.1.37|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /g.samarth/two-params-mcmc ... done.
# ==> SIZE param_coeff_M.npy ... 58586528
# ==> PASV ... done.    ==> RETR param_coeff_M.npy ... done.
# Length: 58586528 (56M) (unauthoritative)
#
# param_coeff_M.npy   100%[===================>]  55.87M  10.3MB/s    in 6.9s
#
# 2021-12-16 16:27:53 (8.06 MB/s) - ‘param_coeff_M.npy’ saved [58586528]
#
# --2021-12-16 16:27:53--  ftp://ftp.tifr.res.in/g.samarth/two-params-mcmc/sparse_idx.npy
#            => ‘sparse_idx.npy’
# Resolving ftp.tifr.res.in (ftp.tifr.res.in)... 158.144.1.37, 2406:f00:1:1::70
# Connecting to ftp.tifr.res.in (ftp.tifr.res.in)|158.144.1.37|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /g.samarth/two-params-mcmc ... done.
# ==> SIZE sparse_idx.npy ... 9764528
# ==> PASV ... done.    ==> RETR sparse_idx.npy ... done.
# Length: 9764528 (9.3M) (unauthoritative)
#
# sparse_idx.npy      100%[===================>]   9.31M  3.80MB/s    in 2.4s
#
# 2021-12-16 16:28:01 (3.80 MB/s) - ‘sparse_idx.npy’ saved [9764528]
#
# --2021-12-16 16:28:01--  ftp://ftp.tifr.res.in/g.samarth/two-params-mcmc/sparse_idx_M.npy
#            => ‘sparse_idx_M.npy’
# Resolving ftp.tifr.res.in (ftp.tifr.res.in)... 158.144.1.37, 2406:f00:1:1::70
# Connecting to ftp.tifr.res.in (ftp.tifr.res.in)|158.144.1.37|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /g.samarth/two-params-mcmc ... done.
# ==> SIZE sparse_idx_M.npy ... 9764528
# ==> PASV ... done.    ==> RETR sparse_idx_M.npy ... done.
# Length: 9764528 (9.3M) (unauthoritative)
#
# sparse_idx_M.npy    100%[===================>]   9.31M  3.53MB/s    in 2.6s
#
# 2021-12-16 16:28:10 (3.53 MB/s) - ‘sparse_idx_M.npy’ saved [9764528]
#
# --2021-12-16 16:28:10--  ftp://ftp.tifr.res.in/g.samarth/two-params-mcmc/fixed_part.npy
#            => ‘fixed_part.npy’
# Resolving ftp.tifr.res.in (ftp.tifr.res.in)... 158.144.1.37, 2406:f00:1:1::70
# Connecting to ftp.tifr.res.in (ftp.tifr.res.in)|158.144.1.37|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /g.samarth/two-params-mcmc ... done.
# ==> SIZE fixed_part.npy ... 4882328
# ==> PASV ... done.    ==> RETR fixed_part.npy ... done.
# Length: 4882328 (4.7M) (unauthoritative)
#
# fixed_part.npy      100%[===================>]   4.66M  2.31MB/s    in 2.0s
#
# 2021-12-16 16:28:16 (2.31 MB/s) - ‘fixed_part.npy’ saved [4882328]
#
# --2021-12-16 16:28:16--  ftp://ftp.tifr.res.in/g.samarth/two-params-mcmc/fixed_part_M.npy
#            => ‘fixed_part_M.npy’
# Resolving ftp.tifr.res.in (ftp.tifr.res.in)... 158.144.1.37, 2406:f00:1:1::70
# Connecting to ftp.tifr.res.in (ftp.tifr.res.in)|158.144.1.37|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /g.samarth/two-params-mcmc ... done.
# ==> SIZE fixed_part_M.npy ... 4882328
# ==> PASV ... done.    ==> RETR fixed_part_M.npy ... done.
# Length: 4882328 (4.7M) (unauthoritative)
#
# fixed_part_M.npy    100%[===================>]   4.66M  2.24MB/s    in 2.1s
#
# 2021-12-16 16:28:22 (2.24 MB/s) - ‘fixed_part_M.npy’ saved [4882328]
#
# --2021-12-16 16:28:22--  ftp://ftp.tifr.res.in/g.samarth/two-params-mcmc/fixed_bkm.npy
#            => ‘fixed_bkm.npy’
# Resolving ftp.tifr.res.in (ftp.tifr.res.in)... 158.144.1.37, 2406:f00:1:1::70
# Connecting to ftp.tifr.res.in (ftp.tifr.res.in)|158.144.1.37|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /g.samarth/two-params-mcmc ... done.
# ==> SIZE fixed_bkm.npy ... 4882328
# ==> PASV ... done.    ==> RETR fixed_bkm.npy ... done.
# Length: 4882328 (4.7M) (unauthoritative)
#
# fixed_bkm.npy       100%[===================>]   4.66M  2.28MB/s    in 2.0s
#
# 2021-12-16 16:28:29 (2.28 MB/s) - ‘fixed_bkm.npy’ saved [4882328]
#
# --2021-12-16 16:28:29--  ftp://ftp.tifr.res.in/g.samarth/two-params-mcmc/noc_bkm.npy
#            => ‘noc_bkm.npy’
# Resolving ftp.tifr.res.in (ftp.tifr.res.in)... 158.144.1.37, 2406:f00:1:1::70
# Connecting to ftp.tifr.res.in (ftp.tifr.res.in)|158.144.1.37|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /g.samarth/two-params-mcmc ... done.
# ==> SIZE noc_bkm.npy ... 58586528
# ==> PASV ... done.    ==> RETR noc_bkm.npy ... done.
# Length: 58586528 (56M) (unauthoritative)
#
# noc_bkm.npy         100%[===================>]  55.87M  10.8MB/s    in 6.7s
#
# 2021-12-16 16:28:40 (8.28 MB/s) - ‘noc_bkm.npy’ saved [58586528]
#
# --2021-12-16 16:28:40--  ftp://ftp.tifr.res.in/g.samarth/two-params-mcmc/k_arr.npy
#            => ‘k_arr.npy’
# Resolving ftp.tifr.res.in (ftp.tifr.res.in)... 158.144.1.37, 2406:f00:1:1::70
# Connecting to ftp.tifr.res.in (ftp.tifr.res.in)|158.144.1.37|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /g.samarth/two-params-mcmc ... done.
# ==> SIZE k_arr.npy ... 4882328
# ==> PASV ... done.    ==> RETR k_arr.npy ... done.
# Length: 4882328 (4.7M) (unauthoritative)
#
# k_arr.npy           100%[===================>]   4.66M  2.24MB/s    in 2.1s
#
# 2021-12-16 16:28:49 (2.24 MB/s) - ‘k_arr.npy’ saved [4882328]
#
# --2021-12-16 16:28:49--  ftp://ftp.tifr.res.in/g.samarth/two-params-mcmc/p_arr.npy
#            => ‘p_arr.npy’
# Resolving ftp.tifr.res.in (ftp.tifr.res.in)... 158.144.1.37, 2406:f00:1:1::70
# Connecting to ftp.tifr.res.in (ftp.tifr.res.in)|158.144.1.37|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /g.samarth/two-params-mcmc ... done.
# ==> SIZE p_arr.npy ... 3288
# ==> PASV ... done.    ==> RETR p_arr.npy ... done.
# Length: 3288 (3.2K) (unauthoritative)
#
# p_arr.npy           100%[===================>]   3.21K  --.-KB/s    in 0s
#
# 2021-12-16 16:28:54 (315 MB/s) - ‘p_arr.npy’ saved [3288]

# %%
import os
import time

import matplotlib.pyplot as plt
import numpy as np
import arviz as az
import argparse
import sys

import jax
import jax.numpy as jnp
from jax import random
from jax.config import config
from jax.experimental import sparse
from jax.lax import fori_loop as foril
from jax.lax import dynamic_slice as jdc
from jax.lax import dynamic_update_slice as jdc_update
from jax.ops import index_update as jidx_update
from jax.ops import index as jidx
config.update('jax_enable_x64', True)

NAX = jnp.newaxis
OM = 2.0963670602632024e-05
num_chains = 1

import numpyro
import numpyro.distributions as dist
from numpyro.infer import NUTS, MCMC, SA

print(jax.devices()) # printing JAX devices

class argparser():
  maxiter = 2000
  warmup = 500
  chain_num = 1
PARSED_ARGS = argparser()

read_params = np.loadtxt(".n0-lmin-lmax.dat")
ARGS = {}
ARGS['n0'] = int(read_params[0])
ARGS['lmin'] = int(read_params[1])
ARGS['lmax'] = int(read_params[2])
ARGS['rth'] = read_params[3]
ARGS['knot_num'] = int(read_params[4])
ARGS['load_from_file'] = int(read_params[5])

################ loading the files for the problem ###############
dim_hyper = int(np.loadtxt('.dimhyper'))

# true params from Antia wsr
true_params = np.load('true_params.npy')
eigvals_true = np.load('evals_model.npy')
acoeffs_true = np.load('acoeffs_true.npy')
acoeffs_sigma = np.load('acoeffs_sigma.npy')

ell0_arr = np.load('ell0_arr.npy')
omega0_arr = np.load('omega0_arr.npy')
dom_dell_arr = np.load('dom_dell_arr.npy').flatten()

cind_arr = np.load('cind_arr.npy')
smin_ind, smax_ind = np.load('sind_arr.npy')
s_arr = np.array([1, 3, 5])

# supermatrix specific files for the exact problem
param_coeff = np.load('param_coeff.npy')
sparse_idx = np.load('sparse_idx.npy')
fixed_part = np.load('fixed_part.npy')
param_coeff = param_coeff[smin_ind:smax_ind+1, ...]
max_nbs = param_coeff.shape[-2]
len_mmax = param_coeff.shape[-1]
max_lmax = int(len_mmax//2)

# supermatrix M specific files for the V11 approximated problem
param_coeff_M = np.load('param_coeff_M.npy')
sparse_idx_M = np.load('sparse_idx_M.npy')
fixed_part_M = np.load('fixed_part_M.npy')
param_coeff_M = param_coeff_M[smin_ind:smax_ind+1, ...]

# reading the bkm values
fixed_part_bkm = np.load('fixed_bkm.npy')
param_coeff_bkm = np.load('noc_bkm.npy')
param_coeff_bkm = param_coeff_bkm[smin_ind:smax_ind+1, ...]
k_arr = np.load('k_arr.npy')
p_arr = np.load('p_arr.npy')

k_arr_denom = k_arr*1
k_arr_denom[k_arr==0] = 1

#################################################################
# number of central multiplets
nmults = len(ell0_arr)
# total number of s for which to create a-coeffs
num_j = len(s_arr)
# number of s to fit
len_s = true_params.shape[0]
# number of c's to fit
nc = true_params.shape[1]
num_params = len(cind_arr)
num_k = (np.unique(k_arr)>0).sum()

#############################################################
# Reading RL poly from precomputed file
# shape (nmults x (smax+1) x 2*ellmax+1)
# reshaping to (nmults x (smax+1) x dim_hyper)
RL_poly = np.load('RL_poly.npy')
smin = min(s_arr)
smax = max(s_arr)
Pjl_read = RL_poly[:, smin:smax+1:2, :]
Pjl = np.zeros((Pjl_read.shape[0],
                Pjl_read.shape[1],
                len_mmax))
Pjl[:, :, :Pjl_read.shape[2]] = Pjl_read

# calculating the normalization for Pjl apriori
# shape (nmults, num_j)
Pjl_norm = np.zeros((nmults, Pjl.shape[1]))
for mult_ind in range(nmults):
    Pjl_norm[mult_ind] = np.diag(Pjl[mult_ind] @ Pjl[mult_ind].T)

ellmax_pjl = int(Pjl_read.shape[-1]//2)
dell = max_lmax - ellmax_pjl
Pjl = np.array(Pjl)
for i in range(nmults):
    dell2 = ellmax_pjl - ell0_arr[i]
    Pjl[i, ...] = np.roll(Pjl[i, ...], dell+dell2, axis=-1)
Pjl = jnp.asarray(Pjl)

#############################################################
# converting to device array
Pjl = jnp.asarray(Pjl)
true_params = jnp.asarray(true_params)
param_coeff = jnp.asarray(param_coeff)
fixed_part = jnp.asarray(fixed_part)

param_coeff_M = jnp.asarray(param_coeff_M)
fixed_part_M = jnp.asarray(fixed_part_M)

param_coeff_bkm = jnp.asarray(param_coeff_bkm)
fixed_part_bkm = jnp.asarray(fixed_part_bkm)
k_arr = jnp.asarray(k_arr)

acoeffs_sigma = jnp.asarray(acoeffs_sigma)
Pjl_norm = jnp.asarray(Pjl_norm)
sparse_idx = jnp.asarray(sparse_idx)
ell0_arr_jax = jnp.asarray(ell0_arr)
omega0_arr_jax = jnp.asarray(omega0_arr)
dom_dell_jax = jnp.asarray(dom_dell_arr)

########################################################################
# reshaping true_params and param_coeff

true_params = jnp.reshape(true_params, (nc * len_s,), 'F')
param_coeff = jnp.reshape(param_coeff, (nc * len_s, nmults,
                                        max_nbs, max_nbs, len_mmax), 'F')
param_coeff_M = jnp.reshape(param_coeff_M, (nc * len_s, nmults,
                                            max_nbs, max_nbs, len_mmax), 'F')
param_coeff_bkm = jnp.reshape(param_coeff_bkm, (nc * len_s, nmults,
                                                max_nbs, max_nbs, len_mmax), 'F')

# moving axis to allow seamless jnp.dot
param_coeff = jnp.moveaxis(param_coeff, 0, -1)
param_coeff_M = jnp.moveaxis(param_coeff_M, 0, -1)
param_coeff_bkm = jnp.moveaxis(param_coeff_bkm, 0, -1)

# setting the prior limits
cmin = 0.8 * jnp.ones_like(true_params)
cmax = 1.2 * jnp.ones_like(true_params)

ctrl_limits = {}
ctrl_limits['cmin'] = cmin
ctrl_limits['cmax'] = cmax

# comparing the matrices with the true values
supmat_jax = param_coeff @ true_params + fixed_part

def get_clp(bkm):
    tvals = jnp.linspace(0, jnp.pi, 25)
    integrand = jnp.zeros((bkm.shape[0],
                           bkm.shape[1],
                           bkm.shape[-1],
                           len(tvals)))

    def t_func(i, intg):
        term2 = 2*bkm*jnp.sin(k_arr*tvals[i])/k_arr_denom
        term2 = term2.sum(axis=(1, 2))[:, NAX, :]
        intg = jidx_update(intg, jidx[:, :, :, i], jnp.cos(p_arr[:, :, NAX]*tvals[i]
                                                           - term2))
        return intg

    integrand = foril(0, len(tvals), t_func, integrand)
    integral = jnp.trapz(integrand, axis=-1, x=tvals)/jnp.pi
    return integral


def get_eig_corr(clp, z1):
    # cZc = jnp.zeros(z1.shape[-1])
    # def m_func(idx, czcm):
    #     czcm = jidx_update(czcm,
    #                        jidx[idx],
    #                        clp.conj()[:, idx] @ (z1[:, :, idx] @ clp[:, idx]))
    #     return czcm
    # return foril(0, len(cZc), m_func, cZc)
    cZc = clp.conj() * ((z1 * clp[:, NAX, :]).sum(axis=0))
    return cZc.sum(axis=0)


def compare_model():
    # predicted a-coeficients
    eigvals_compute = jnp.array([])
    eigvals_acoeffs = jnp.array([])
    pred_acoeffs = jnp.zeros(num_j * nmults)

    def scale_bkm(mult_idx, bkm_full):
        bkm_full = jidx_update(bkm_full,
                               jidx[i, :, :, :],
                               -1.0*bkm_full[mult_idx, ...]/dom_dell_jax[mult_idx])
        return bkm_full

    z0 = param_coeff_M @ true_params + fixed_part_M
    zfull = param_coeff @ true_params + fixed_part
    bkm = param_coeff_bkm @ true_params + fixed_part_bkm
    bkm = foril(0, nmults, scale_bkm, bkm)
    clp = get_clp(bkm)

    def loop_in_mults(mult_ind, pred_acoeff):
        ell0 = ell0_arr_jax[mult_ind]
        omegaref = omega0_arr_jax[mult_ind]

        z0mult = z0[mult_ind]
        z1mult = zfull[mult_ind]/2./omegaref - z0mult

        _eigval0mult = get_eig_corr(clp[mult_ind], z0mult)*OM*1e6
        _eigval1mult = get_eig_corr(clp[mult_ind], z1mult)*OM*1e6
        _eigval_mult = _eigval0mult + _eigval1mult

        Pjl_local = Pjl[mult_ind]
        pred_acoeff = jdc_update(pred_acoeff,
                                 (Pjl_local @ _eigval_mult)/Pjl_norm[mult_ind],
                                 (mult_ind * num_j,))
        return pred_acoeff

    pred_acoeffs = foril(0, nmults, loop_in_mults, pred_acoeffs)
    return pred_acoeffs

compare_model_ = jax.jit(compare_model)


def model():
    c_arr = numpyro.sample(f'c_arr', dist.Uniform(cmin, cmax))
    pred_acoeffs = jnp.zeros(num_j * nmults)
    c_params = c_arr * true_params

    def scale_bkm(mult_idx, bkm_full):
        bkm_full = jidx_update(bkm_full,
                               jidx[i, :, :, :],
                               -1.0*bkm_full[mult_idx, ...]/dom_dell_jax[mult_idx])
        return bkm_full

    z0 = param_coeff_M @ c_params + fixed_part_M
    zfull = param_coeff @ c_params + fixed_part
    bkm = param_coeff_bkm @ c_params + fixed_part_bkm
    bkm = foril(0, nmults, scale_bkm, bkm)
    clp = get_clp(bkm)

    def loop_in_mults(mult_ind, pred_acoeff):
        ell0 = ell0_arr_jax[mult_ind]
        omegaref = omega0_arr_jax[mult_ind]

        z0mult = z0[mult_ind]
        z1mult = zfull[mult_ind]/2./omegaref - z0mult

        _eigval0mult = get_eig_corr(clp[mult_ind], z0mult)*OM*1e6
        _eigval1mult = get_eig_corr(clp[mult_ind], z1mult)*OM*1e6
        _eigval_mult = _eigval0mult + _eigval1mult

        Pjl_local = Pjl[mult_ind]
        pred_acoeff = jdc_update(pred_acoeff,
                                 (Pjl_local @ _eigval_mult)/Pjl_norm[mult_ind],
                                 (mult_ind * num_j,))
        return pred_acoeff


    pred_acoeffs = foril(0, nmults, loop_in_mults, pred_acoeffs)
    misfit_acoeffs = (pred_acoeffs[7:] - acoeffs_true[7:])/acoeffs_sigma[7:]
    return numpyro.factor('obs', dist.Normal(0.0, 1.0).log_prob(misfit_acoeffs))


def eigval_sort_slice(eigval, eigvec):
    def body_func(i, ebs):
        return jidx_update(ebs, jidx[i], jnp.argmax(jnp.abs(eigvec[i])))

    eigbasis_sort = jnp.zeros(len(eigval), dtype=int)
    eigbasis_sort = foril(0, len(eigval), body_func, eigbasis_sort)
    return eigval[eigbasis_sort]


def get_eigs(mat):
    eigvals, eigvecs = jnp.linalg.eigh(mat)
    eigvals = eigval_sort_slice(eigvals, eigvecs)
    return eigvals


def print_summary(samples, ctrl_arr):
    count = 0
    for i in range(len(true_params)):
        sample = samples['c_arr'][:, i] * true_params[i]
        obs = true_params[i] 
        print(f"[{obs:11.4e}] c_arr[{i}]: {sample.mean():.4e} +/- {sample.std():.4e}:" +
              f"error/sigma = {(sample.mean()-obs)/sample.std():8.3f}")
    return None


def test_setup():
    acoeffs_model = compare_model_()
    diff = acoeffs_model - acoeffs_true
    len_acoeffs = len(acoeffs_model)
    print(f"{'ell':^6}   |" +
          f"{'Model':^12}   |" +
          f"{'True':^12}   |" +
          f"{'Diff':^12}   |" +
          f"{'Diff/sigma':^12}\n" + 
          f"-----------------------------------------------------------------------")
    mult_idx = 0
    for i in range(len_acoeffs):
        print(f"{ell0_arr_jax[mult_idx]:^6}   |" +
              f"{acoeffs_model[i]*1e3:12.5f}   |" +
              f"{acoeffs_true[i]*1e3:12.5f}   |" +
              f"{diff[i]*1e3:12.5f}   |" +
              f"{diff[i]/acoeffs_sigma[i]:12.5f}")
        if (i+1)%3==0:
          print(f"-------------------------------------------------------------------")
          mult_idx += 1

    t1 = time.time()
    N = 50
    count = 0
    for i in range(N):
        _temp = compare_model_()
        count += _temp.sum()/N
    t2 = time.time()
    print(f"Total time taken for {nmults} modes = {(t2-t1)/N:.3e} seconds")


if __name__ == "__main__":
    test_setup()

    # Start from this source of randomness. We will split keys for subsequent operations.
    seed = int(123 + 100*np.random.rand())
    rng_key = random.PRNGKey(seed)
    rng_key, rng_key_ = random.split(rng_key)
    # sys.exit()

    kernel = NUTS(model, max_tree_depth=(5, 4),
                  find_heuristic_step_size=True)
    mcmc = MCMC(kernel,
                num_warmup=PARSED_ARGS.warmup,
                num_samples=PARSED_ARGS.maxiter,
                num_chains=num_chains)  
    mcmc.run(rng_key_, extra_fields=('potential_energy',))
    pe = mcmc.get_extra_fields()['potential_energy']

    # extracting necessary fields for plotting
